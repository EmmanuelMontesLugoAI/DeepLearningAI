# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanuelMontesLugoAI/DeepLearningAI/blob/main/Actividad_Ejercicio_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML regresión logística y Métricas de desempeño- Riesgo Crediticio

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "/content/SouthGermanCredit.asc"
path2 = "https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/german.data"
data = pd.read_csv(path, sep=" ", header=None)
data
# Out:
#             0         1      2     3      4         5        6     7       8   \
# 0     laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges
# 1            1        18      4     2   1049         1        2     4       2
# 2            1         9      4     0   2799         1        3     2       3
# 3            2        12      2     9    841         2        4     2       2
# 4            1        12      4     0   2122         1        3     3       3
# ...        ...       ...    ...   ...    ...       ...      ...   ...     ...
# 996          1        24      2     3   1987         1        3     2       3
# 997          1        24      2     0   2303         1        5     4       3
# 998          4        21      4     0  12680         5        5     4       3
# 999          2        12      2     3   6468         5        1     2       3
# 1000         1        30      2     2   6350         5        5     4       3
#
# ...
